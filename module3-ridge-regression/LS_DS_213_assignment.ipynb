# %% [markdown]
# <a href="https://colab.research.google.com/github/daanishrasheed/DS-Unit-2-Linear-Models/blob/master/module3-ridge-regression/LS_DS_213_assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Lambda School Data Science
#
# *Unit 2, Sprint 1, Module 3*
#
# ---

# %% [markdown]
# # Ridge Regression
#
# ## Assignment
#
# We're going back to our other **New York City** real estate dataset. Instead of predicting apartment rents, you'll predict property sales prices.
#
# But not just for condos in Tribeca...
#
# Instead, predict property sales prices for **One Family Dwellings** (`BUILDING_CLASS_CATEGORY` == `'01 ONE FAMILY DWELLINGS'`).
#
# Use a subset of the data where the **sale price was more than \\$100 thousand and less than $2 million.**
#
# The [NYC Department of Finance](https://www1.nyc.gov/site/finance/taxes/property-rolling-sales-data.page) has a glossary of property sales terms and NYC Building Class Code Descriptions. The data comes from the [NYC OpenData](https://data.cityofnewyork.us/browse?q=NYC%20calendar%20sales) portal.
#
# - [ ] Do train/test split. Use data from January — March 2019 to train. Use data from April 2019 to test.
# - [ ] Do one-hot encoding of categorical features.
# - [ ] Do feature selection with `SelectKBest`.
# - [ ] Do [feature scaling](https://scikit-learn.org/stable/modules/preprocessing.html).
# - [ ] Fit a ridge regression model with multiple features.
# - [ ] Get mean absolute error for the test set.
# - [ ] As always, commit your notebook to your fork of the GitHub repo.
#
#
# ## Stretch Goals
# - [ ] Add your own stretch goal(s) !
# - [ ] Instead of `Ridge`, try `LinearRegression`. Depending on how many features you select, your errors will probably blow up! 💥
# - [ ] Instead of `Ridge`, try [`RidgeCV`](https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.RidgeCV.html).
# - [ ] Learn more about feature selection:
#     - ["Permutation importance"](https://www.kaggle.com/dansbecker/permutation-importance)
#     - [scikit-learn's User Guide for Feature Selection](https://scikit-learn.org/stable/modules/feature_selection.html)
#     - [mlxtend](http://rasbt.github.io/mlxtend/) library
#     - scikit-learn-contrib libraries: [boruta_py](https://github.com/scikit-learn-contrib/boruta_py) & [stability-selection](https://github.com/scikit-learn-contrib/stability-selection)
#     - [_Feature Engineering and Selection_](http://www.feat.engineering/) by Kuhn & Johnson.
# - [ ] Try [statsmodels](https://www.statsmodels.org/stable/index.html) if you’re interested in more inferential statistical approach to linear regression and feature selection, looking at p values and 95% confidence intervals for the coefficients.
# - [ ] Read [_An Introduction to Statistical Learning_](http://faculty.marshall.usc.edu/gareth-james/ISL/ISLR%20Seventh%20Printing.pdf), Chapters 1-3, for more math & theory, but in an accessible, readable way.
# - [ ] Try [scikit-learn pipelines](https://scikit-learn.org/stable/modules/compose.html).

# %%
# %%capture
import sys

# If you're on Colab:
if 'google.colab' in sys.modules:
    DATA_PATH = 'https://raw.githubusercontent.com/LambdaSchool/DS-Unit-2-Applied-Modeling/master/data/'
    # !pip install category_encoders==2.*

# If you're working locally:
else:
    DATA_PATH = '../data/'
    
# Ignore this Numpy warning when using Plotly Express:
# FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
import warnings
warnings.filterwarnings(action='ignore', category=FutureWarning, module='numpy')

# %%
import pandas as pd
import pandas_profiling

# Read New York City property sales data
df = pd.read_csv(DATA_PATH+'condos/NYC_Citywide_Rolling_Calendar_Sales.csv')

# Change column names: replace spaces with underscores
df.columns = [col.replace(' ', '_') for col in df]

# SALE_PRICE was read as strings.
# Remove symbols, convert to integer
df['SALE_PRICE'] = (
    df['SALE_PRICE']
    .str.replace('$','')
    .str.replace('-','')
    .str.replace(',','')
    .astype(int)
)

# %%
# BOROUGH is a numeric column, but arguably should be a categorical feature,
# so convert it from a number to a string
df['BOROUGH'] = df['BOROUGH'].astype(str)

# %%
# Reduce cardinality for NEIGHBORHOOD feature

# Get a list of the top 10 neighborhoods
top10 = df['NEIGHBORHOOD'].value_counts()[:10].index

# At locations where the neighborhood is NOT in the top 10, 
# replace the neighborhood with 'OTHER'
df.loc[~df['NEIGHBORHOOD'].isin(top10), 'NEIGHBORHOOD'] = 'OTHER'

# %%
df.head()
# Out:
#   BOROUGH             NEIGHBORHOOD  ... SALE_PRICE   SALE_DATE
# 0       1                    OTHER  ...          0  01/01/2019
# 1       1                    OTHER  ...          0  01/01/2019
# 2       1                    OTHER  ...          0  01/01/2019
# 3       1                    OTHER  ...          0  01/01/2019
# 4       1  UPPER EAST SIDE (59-79)  ...          0  01/01/2019
#
# [5 rows x 21 columns]

# %%
df['SALE_DATE'] = pd.to_datetime(df['SALE_DATE'], infer_datetime_format=True)
df['SALE_DATE'].describe()
# Out:
# count                   23040
# unique                    120
# top       2019-01-24 00:00:00
# freq                      480
# first     2019-01-01 00:00:00
# last      2019-04-30 00:00:00
# Name: SALE_DATE, dtype: object

# %%
df['SALE_DATE'].dt.month.value_counts()
# Out:
# 1    6464
# 3    6105
# 2    5598
# 4    4873
# Name: SALE_DATE, dtype: int64

# %%
train = df[df.SALE_DATE.dt.month < 4]
test  = df[df.SALE_DATE.dt.month == 4]
train.shape, test.shape
# Out:
# ((18167, 21), (4873, 21))

# %%
train.select_dtypes(include='number').describe().T
# Out:
#                              count          mean  ...       75%          max
# BLOCK                      18167.0  4.447262e+03  ...    6656.0      16350.0
# LOT                        18167.0  3.436415e+02  ...     286.0       9022.0
# EASE-MENT                      0.0           NaN  ...       NaN          NaN
# ZIP_CODE                   18167.0  1.078270e+04  ...   11360.0      11697.0
# RESIDENTIAL_UNITS          18167.0  1.721418e+00  ...       2.0        750.0
# COMMERCIAL_UNITS           18167.0  2.989486e-01  ...       0.0        570.0
# TOTAL_UNITS                18167.0  2.172235e+00  ...       2.0        755.0
# GROSS_SQUARE_FEET          18167.0  3.214913e+03  ...    2273.5    1303935.0
# YEAR_BUILT                 18162.0  1.822193e+03  ...    1965.0       2019.0
# TAX_CLASS_AT_TIME_OF_SALE  18167.0  1.617053e+00  ...       2.0          4.0
# SALE_PRICE                 18167.0  1.217331e+06  ...  840056.0  850000000.0
#
# [11 rows x 8 columns]

# %%
train.select_dtypes(exclude='number').describe().T.sort_values(by='unique')
# Out:
#                                 count unique  ...      first       last
# BOROUGH                         18167      5  ...        NaT        NaT
# TAX_CLASS_AT_PRESENT            18167     10  ...        NaT        NaT
# NEIGHBORHOOD                    18167     11  ...        NaT        NaT
# BUILDING_CLASS_CATEGORY         18167     43  ...        NaT        NaT
# SALE_DATE                       18167     90  ... 2019-01-01 2019-03-31
# BUILDING_CLASS_AT_PRESENT       18167    140  ...        NaT        NaT
# BUILDING_CLASS_AT_TIME_OF_SALE  18167    140  ...        NaT        NaT
# APARTMENT_NUMBER                 3972   1450  ...        NaT        NaT
# LAND_SQUARE_FEET                18139   3207  ...        NaT        NaT
# ADDRESS                         18167  17926  ...        NaT        NaT
#
# [10 rows x 6 columns]

# %%
train.groupby('NEIGHBORHOOD')['SALE_PRICE'].describe()
# Out:
#                            count          mean  ...        75%          max
# NEIGHBORHOOD                                    ...
# ASTORIA                    266.0  2.134987e+06  ...   919375.0   75000000.0
# BEDFORD STUYVESANT         335.0  9.473171e+05  ...  1117500.0   32500000.0
# BOROUGH PARK               285.0  4.562094e+05  ...   865000.0    9650000.0
# FLUSHING-NORTH             549.0  6.626492e+05  ...   836000.0   40433512.0
# FOREST HILLS               237.0  5.214604e+05  ...   675000.0    6205000.0
# GRAMERCY                   282.0  8.226612e+05  ...  1043750.0   18000000.0
# OTHER                    15058.0  1.197267e+06  ...   800000.0  850000000.0
# UPPER EAST SIDE (59-79)    343.0  3.335407e+06  ...  2500000.0   68000000.0
# UPPER EAST SIDE (79-96)    314.0  1.737515e+06  ...  1668750.0   90500000.0
# UPPER WEST SIDE (59-79)    280.0  1.302832e+06  ...  1700000.0   18000000.0
# UPPER WEST SIDE (79-96)    218.0  1.365809e+06  ...  1750000.0   11509225.0
#
# [11 rows x 8 columns]

# %%
train.groupby('NEIGHBORHOOD')['SALE_PRICE'].mean()
# Out:
# NEIGHBORHOOD
# ASTORIA                    2.134987e+06
# BEDFORD STUYVESANT         9.473171e+05
# BOROUGH PARK               4.562094e+05
# FLUSHING-NORTH             6.626492e+05
# FOREST HILLS               5.214604e+05
# GRAMERCY                   8.226612e+05
# OTHER                      1.197267e+06
# UPPER EAST SIDE (59-79)    3.335407e+06
# UPPER EAST SIDE (79-96)    1.737515e+06
# UPPER WEST SIDE (59-79)    1.302832e+06
# UPPER WEST SIDE (79-96)    1.365809e+06
# Name: SALE_PRICE, dtype: float64

# %%
target = 'SALE_PRICE'
high_cardinality = ['ADDRESS', 'LAND_SQUARE_FEET', 'APARTMENT_NUMBER', 'BLOCK', 'LOT', 'EASE-MENT', 'ZIP_CODE', 'RESIDENTIAL_UNITS', 'COMMERCIAL_UNITS', 'TOTAL_UNITS', 'GROSS_SQUARE_FEET', 'YEAR_BUILT', 'TAX_CLASS_AT_TIME_OF_SALE', 'SALE_DATE']
features = train.columns.drop([target] + high_cardinality)

X_train = train[features]
y_train = train[target]
X_test = test[features]
y_test = test[target]

# %%
X_train.head()
# Out:
#   BOROUGH  ... BUILDING_CLASS_AT_TIME_OF_SALE
# 0       1  ...                             R4
# 1       1  ...                             O5
# 2       1  ...                             O5
# 3       1  ...                             R4
# 4       1  ...                             R1
#
# [5 rows x 6 columns]

# %%
import category_encoders as ce
encoder = ce.OneHotEncoder(use_cat_names=True)
X_train = encoder.fit_transform(X_train)
X_test = encoder.transform(X_test)

# %%
X_train.head()
# Out:
#    BOROUGH_1  ...  BUILDING_CLASS_AT_TIME_OF_SALE_K6
# 0          1  ...                                  0
# 1          1  ...                                  0
# 2          1  ...                                  0
# 3          1  ...                                  0
# 4          1  ...                                  0
#
# [5 rows x 349 columns]

# %%
from sklearn.feature_selection import f_regression, SelectKBest

selector = SelectKBest(score_func=f_regression, k = 10)
X_train_selected = selector.fit_transform(X_train, y_train)
X_test_selected = selector.transform(X_test)

# %%
all_names = X_train.columns
selected_mask = selector.get_support()
selected_names = all_names[selected_mask]
unselected_names = all_names[~selected_mask]

print('Features selected:')
for name in selected_names:
    print(name)

print('\n')
print('Features not selected:')
for name in unselected_names:
    print(name)
# Out:
# Features selected:
# BUILDING_CLASS_CATEGORY_25 LUXURY HOTELS
# TAX_CLASS_AT_PRESENT_4
# BUILDING_CLASS_AT_PRESENT_O4
# BUILDING_CLASS_AT_PRESENT_H1
# BUILDING_CLASS_AT_PRESENT_D8
# BUILDING_CLASS_AT_PRESENT_K3
# BUILDING_CLASS_AT_TIME_OF_SALE_O4
# BUILDING_CLASS_AT_TIME_OF_SALE_H1
# BUILDING_CLASS_AT_TIME_OF_SALE_D8
# BUILDING_CLASS_AT_TIME_OF_SALE_K3
#
#
# Features not selected:
# BOROUGH_1
# BOROUGH_2
# BOROUGH_3
# BOROUGH_4
# BOROUGH_5
# NEIGHBORHOOD_OTHER
# NEIGHBORHOOD_UPPER EAST SIDE (59-79)
# NEIGHBORHOOD_UPPER EAST SIDE (79-96)
# NEIGHBORHOOD_BOROUGH PARK
# NEIGHBORHOOD_ASTORIA
# NEIGHBORHOOD_FOREST HILLS
# NEIGHBORHOOD_UPPER WEST SIDE (59-79)
# NEIGHBORHOOD_UPPER WEST SIDE (79-96)
# NEIGHBORHOOD_BEDFORD STUYVESANT
# NEIGHBORHOOD_FLUSHING-NORTH
# NEIGHBORHOOD_GRAMERCY
# BUILDING_CLASS_CATEGORY_13 CONDOS - ELEVATOR APARTMENTS
# BUILDING_CLASS_CATEGORY_21 OFFICE BUILDINGS
# BUILDING_CLASS_CATEGORY_15 CONDOS - 2-10 UNIT RESIDENTIAL
# BUILDING_CLASS_CATEGORY_07 RENTALS - WALKUP APARTMENTS
# BUILDING_CLASS_CATEGORY_01 ONE FAMILY DWELLINGS
# BUILDING_CLASS_CATEGORY_02 TWO FAMILY DWELLINGS
# BUILDING_CLASS_CATEGORY_05 TAX CLASS 1 VACANT LAND
# BUILDING_CLASS_CATEGORY_29 COMMERCIAL GARAGES
# BUILDING_CLASS_CATEGORY_32 HOSPITAL AND HEALTH FACILITIES
# BUILDING_CLASS_CATEGORY_33 EDUCATIONAL FACILITIES
# BUILDING_CLASS_CATEGORY_08 RENTALS - ELEVATOR APARTMENTS
# BUILDING_CLASS_CATEGORY_31 COMMERCIAL VACANT LAND
# BUILDING_CLASS_CATEGORY_41 TAX CLASS 4 - OTHER
# BUILDING_CLASS_CATEGORY_14 RENTALS - 4-10 UNIT
# BUILDING_CLASS_CATEGORY_03 THREE FAMILY DWELLINGS
# BUILDING_CLASS_CATEGORY_22 STORE BUILDINGS
# BUILDING_CLASS_CATEGORY_10 COOPS - ELEVATOR APARTMENTS
# BUILDING_CLASS_CATEGORY_44 CONDO PARKING
# BUILDING_CLASS_CATEGORY_47 CONDO NON-BUSINESS STORAGE
# BUILDING_CLASS_CATEGORY_12 CONDOS - WALKUP APARTMENTS
# BUILDING_CLASS_CATEGORY_43 CONDO OFFICE BUILDINGS
# BUILDING_CLASS_CATEGORY_09 COOPS - WALKUP APARTMENTS
# BUILDING_CLASS_CATEGORY_27 FACTORIES
# BUILDING_CLASS_CATEGORY_04 TAX CLASS 1 CONDOS
# BUILDING_CLASS_CATEGORY_17 CONDO COOPS
# BUILDING_CLASS_CATEGORY_26 OTHER HOTELS
# BUILDING_CLASS_CATEGORY_45 CONDO HOTELS
# BUILDING_CLASS_CATEGORY_06 TAX CLASS 1 - OTHER
# BUILDING_CLASS_CATEGORY_30 WAREHOUSES
# BUILDING_CLASS_CATEGORY_46 CONDO STORE BUILDINGS
# BUILDING_CLASS_CATEGORY_34 THEATRES
# BUILDING_CLASS_CATEGORY_37 RELIGIOUS FACILITIES
# BUILDING_CLASS_CATEGORY_49 CONDO WAREHOUSES/FACTORY/INDUS
# BUILDING_CLASS_CATEGORY_16 CONDOS - 2-10 UNIT WITH COMMERCIAL UNIT
# BUILDING_CLASS_CATEGORY_11A CONDO-RENTALS
# BUILDING_CLASS_CATEGORY_36 OUTDOOR RECREATIONAL FACILITIES
# BUILDING_CLASS_CATEGORY_23 LOFT BUILDINGS
# BUILDING_CLASS_CATEGORY_28 COMMERCIAL CONDOS
# BUILDING_CLASS_CATEGORY_48 CONDO TERRACES/GARDENS/CABANAS
# BUILDING_CLASS_CATEGORY_35 INDOOR PUBLIC AND CULTURAL FACILITIES
# BUILDING_CLASS_CATEGORY_39 TRANSPORTATION FACILITIES
# BUILDING_CLASS_CATEGORY_42 CONDO CULTURAL/MEDICAL/EDUCATIONAL/ETC
# TAX_CLASS_AT_PRESENT_2
# TAX_CLASS_AT_PRESENT_2C
# TAX_CLASS_AT_PRESENT_2B
# TAX_CLASS_AT_PRESENT_1
# TAX_CLASS_AT_PRESENT_1B
# TAX_CLASS_AT_PRESENT_2A
# TAX_CLASS_AT_PRESENT_1A
# TAX_CLASS_AT_PRESENT_1C
# TAX_CLASS_AT_PRESENT_1D
# BUILDING_CLASS_AT_PRESENT_R4
# BUILDING_CLASS_AT_PRESENT_O5
# BUILDING_CLASS_AT_PRESENT_R1
# BUILDING_CLASS_AT_PRESENT_C4
# BUILDING_CLASS_AT_PRESENT_A1
# BUILDING_CLASS_AT_PRESENT_A5
# BUILDING_CLASS_AT_PRESENT_B1
# BUILDING_CLASS_AT_PRESENT_V0
# BUILDING_CLASS_AT_PRESENT_G7
# BUILDING_CLASS_AT_PRESENT_I9
# BUILDING_CLASS_AT_PRESENT_W6
# BUILDING_CLASS_AT_PRESENT_D3
# BUILDING_CLASS_AT_PRESENT_O7
# BUILDING_CLASS_AT_PRESENT_G1
# BUILDING_CLASS_AT_PRESENT_V1
# BUILDING_CLASS_AT_PRESENT_I1
# BUILDING_CLASS_AT_PRESENT_W9
# BUILDING_CLASS_AT_PRESENT_Z9
# BUILDING_CLASS_AT_PRESENT_S3
# BUILDING_CLASS_AT_PRESENT_V6
# BUILDING_CLASS_AT_PRESENT_C0
# BUILDING_CLASS_AT_PRESENT_S2
# BUILDING_CLASS_AT_PRESENT_C2
# BUILDING_CLASS_AT_PRESENT_K1
# BUILDING_CLASS_AT_PRESENT_B9
# BUILDING_CLASS_AT_PRESENT_A9
# BUILDING_CLASS_AT_PRESENT_C3
# BUILDING_CLASS_AT_PRESENT_A3
# BUILDING_CLASS_AT_PRESENT_B3
# BUILDING_CLASS_AT_PRESENT_D4
# BUILDING_CLASS_AT_PRESENT_B2
# BUILDING_CLASS_AT_PRESENT_C7
# BUILDING_CLASS_AT_PRESENT_D6
# BUILDING_CLASS_AT_PRESENT_C1
# BUILDING_CLASS_AT_PRESENT_RP
# BUILDING_CLASS_AT_PRESENT_RS
# BUILDING_CLASS_AT_PRESENT_A2
# BUILDING_CLASS_AT_PRESENT_R2
# BUILDING_CLASS_AT_PRESENT_A0
# BUILDING_CLASS_AT_PRESENT_RB
# BUILDING_CLASS_AT_PRESENT_D7
# BUILDING_CLASS_AT_PRESENT_S1
# BUILDING_CLASS_AT_PRESENT_C6
# BUILDING_CLASS_AT_PRESENT_F5
# BUILDING_CLASS_AT_PRESENT_R3
# BUILDING_CLASS_AT_PRESENT_R9
# BUILDING_CLASS_AT_PRESENT_H3
# BUILDING_CLASS_AT_PRESENT_RH
# BUILDING_CLASS_AT_PRESENT_G2
# BUILDING_CLASS_AT_PRESENT_Z0
# BUILDING_CLASS_AT_PRESENT_S9
# BUILDING_CLASS_AT_PRESENT_A7
# BUILDING_CLASS_AT_PRESENT_G0
# BUILDING_CLASS_AT_PRESENT_K2
# BUILDING_CLASS_AT_PRESENT_D0
# BUILDING_CLASS_AT_PRESENT_K8
# BUILDING_CLASS_AT_PRESENT_A4
# BUILDING_CLASS_AT_PRESENT_R6
# BUILDING_CLASS_AT_PRESENT_RG
# BUILDING_CLASS_AT_PRESENT_E1
# BUILDING_CLASS_AT_PRESENT_I6
# BUILDING_CLASS_AT_PRESENT_A6
# BUILDING_CLASS_AT_PRESENT_C5
# BUILDING_CLASS_AT_PRESENT_C8
# BUILDING_CLASS_AT_PRESENT_K4
# BUILDING_CLASS_AT_PRESENT_S5
# BUILDING_CLASS_AT_PRESENT_D1
# BUILDING_CLASS_AT_PRESENT_F9
# BUILDING_CLASS_AT_PRESENT_O9
# BUILDING_CLASS_AT_PRESENT_A8
# BUILDING_CLASS_AT_PRESENT_E9
# BUILDING_CLASS_AT_PRESENT_RK
# BUILDING_CLASS_AT_PRESENT_O6
# BUILDING_CLASS_AT_PRESENT_S4
# BUILDING_CLASS_AT_PRESENT_J1
# BUILDING_CLASS_AT_PRESENT_G6
# BUILDING_CLASS_AT_PRESENT_M1
# BUILDING_CLASS_AT_PRESENT_D9
# BUILDING_CLASS_AT_PRESENT_G3
# BUILDING_CLASS_AT_PRESENT_J6
# BUILDING_CLASS_AT_PRESENT_O2
# BUILDING_CLASS_AT_PRESENT_W2
# BUILDING_CLASS_AT_PRESENT_R7
# BUILDING_CLASS_AT_PRESENT_GW
# BUILDING_CLASS_AT_PRESENT_K9
# BUILDING_CLASS_AT_PRESENT_C9
# BUILDING_CLASS_AT_PRESENT_F1
# BUILDING_CLASS_AT_PRESENT_K7
# BUILDING_CLASS_AT_PRESENT_RW
# BUILDING_CLASS_AT_PRESENT_J2
# BUILDING_CLASS_AT_PRESENT_O8
# BUILDING_CLASS_AT_PRESENT_O1
# BUILDING_CLASS_AT_PRESENT_F4
# BUILDING_CLASS_AT_PRESENT_R8
# BUILDING_CLASS_AT_PRESENT_D2
# BUILDING_CLASS_AT_PRESENT_K5
# BUILDING_CLASS_AT_PRESENT_F8
# BUILDING_CLASS_AT_PRESENT_M9
# BUILDING_CLASS_AT_PRESENT_RR
# BUILDING_CLASS_AT_PRESENT_Q9
# BUILDING_CLASS_AT_PRESENT_M3
# BUILDING_CLASS_AT_PRESENT_S0
# BUILDING_CLASS_AT_PRESENT_Z2
# BUILDING_CLASS_AT_PRESENT_L9
# BUILDING_CLASS_AT_PRESENT_E7
# BUILDING_CLASS_AT_PRESENT_J9
# BUILDING_CLASS_AT_PRESENT_E2
# BUILDING_CLASS_AT_PRESENT_W8
# BUILDING_CLASS_AT_PRESENT_R5
# BUILDING_CLASS_AT_PRESENT_HB
# BUILDING_CLASS_AT_PRESENT_H9
# BUILDING_CLASS_AT_PRESENT_HR
# BUILDING_CLASS_AT_PRESENT_I4
# BUILDING_CLASS_AT_PRESENT_G8
# BUILDING_CLASS_AT_PRESENT_H7
# BUILDING_CLASS_AT_PRESENT_G9
# BUILDING_CLASS_AT_PRESENT_I5
# BUILDING_CLASS_AT_PRESENT_V9
# BUILDING_CLASS_AT_PRESENT_RT
# BUILDING_CLASS_AT_PRESENT_P8
# BUILDING_CLASS_AT_PRESENT_H2
# BUILDING_CLASS_AT_PRESENT_Z4
# BUILDING_CLASS_AT_PRESENT_L8
# BUILDING_CLASS_AT_PRESENT_P2
# BUILDING_CLASS_AT_PRESENT_L1
# BUILDING_CLASS_AT_PRESENT_V3
# BUILDING_CLASS_AT_PRESENT_T2
# BUILDING_CLASS_AT_PRESENT_RA
# BUILDING_CLASS_AT_PRESENT_G4
# BUILDING_CLASS_AT_PRESENT_V2
# BUILDING_CLASS_AT_PRESENT_P9
# BUILDING_CLASS_AT_PRESENT_W4
# BUILDING_CLASS_AT_PRESENT_W3
# BUILDING_CLASS_AT_PRESENT_I7
# BUILDING_CLASS_AT_PRESENT_H4
# BUILDING_CLASS_AT_PRESENT_K6
# BUILDING_CLASS_AT_TIME_OF_SALE_R4
# BUILDING_CLASS_AT_TIME_OF_SALE_O5
# BUILDING_CLASS_AT_TIME_OF_SALE_R1
# BUILDING_CLASS_AT_TIME_OF_SALE_C4
# BUILDING_CLASS_AT_TIME_OF_SALE_A1
# BUILDING_CLASS_AT_TIME_OF_SALE_A5
# BUILDING_CLASS_AT_TIME_OF_SALE_B1
# BUILDING_CLASS_AT_TIME_OF_SALE_V0
# BUILDING_CLASS_AT_TIME_OF_SALE_G7
# BUILDING_CLASS_AT_TIME_OF_SALE_I9
# BUILDING_CLASS_AT_TIME_OF_SALE_W6
# BUILDING_CLASS_AT_TIME_OF_SALE_D3
# BUILDING_CLASS_AT_TIME_OF_SALE_O7
# BUILDING_CLASS_AT_TIME_OF_SALE_G1
# BUILDING_CLASS_AT_TIME_OF_SALE_V1
# BUILDING_CLASS_AT_TIME_OF_SALE_I1
# BUILDING_CLASS_AT_TIME_OF_SALE_W9
# BUILDING_CLASS_AT_TIME_OF_SALE_Z9
# BUILDING_CLASS_AT_TIME_OF_SALE_S3
# BUILDING_CLASS_AT_TIME_OF_SALE_V6
# BUILDING_CLASS_AT_TIME_OF_SALE_C0
# BUILDING_CLASS_AT_TIME_OF_SALE_S2
# BUILDING_CLASS_AT_TIME_OF_SALE_C2
# BUILDING_CLASS_AT_TIME_OF_SALE_K1
# BUILDING_CLASS_AT_TIME_OF_SALE_B9
# BUILDING_CLASS_AT_TIME_OF_SALE_A9
# BUILDING_CLASS_AT_TIME_OF_SALE_C3
# BUILDING_CLASS_AT_TIME_OF_SALE_A3
# BUILDING_CLASS_AT_TIME_OF_SALE_B3
# BUILDING_CLASS_AT_TIME_OF_SALE_D4
# BUILDING_CLASS_AT_TIME_OF_SALE_B2
# BUILDING_CLASS_AT_TIME_OF_SALE_C7
# BUILDING_CLASS_AT_TIME_OF_SALE_D6
# BUILDING_CLASS_AT_TIME_OF_SALE_C1
# BUILDING_CLASS_AT_TIME_OF_SALE_RP
# BUILDING_CLASS_AT_TIME_OF_SALE_RS
# BUILDING_CLASS_AT_TIME_OF_SALE_A2
# BUILDING_CLASS_AT_TIME_OF_SALE_R2
# BUILDING_CLASS_AT_TIME_OF_SALE_A0
# BUILDING_CLASS_AT_TIME_OF_SALE_RB
# BUILDING_CLASS_AT_TIME_OF_SALE_D7
# BUILDING_CLASS_AT_TIME_OF_SALE_S1
# BUILDING_CLASS_AT_TIME_OF_SALE_C6
# BUILDING_CLASS_AT_TIME_OF_SALE_F5
# BUILDING_CLASS_AT_TIME_OF_SALE_R3
# BUILDING_CLASS_AT_TIME_OF_SALE_R9
# BUILDING_CLASS_AT_TIME_OF_SALE_H3
# BUILDING_CLASS_AT_TIME_OF_SALE_RH
# BUILDING_CLASS_AT_TIME_OF_SALE_G2
# BUILDING_CLASS_AT_TIME_OF_SALE_Z0
# BUILDING_CLASS_AT_TIME_OF_SALE_S9
# BUILDING_CLASS_AT_TIME_OF_SALE_A7
# BUILDING_CLASS_AT_TIME_OF_SALE_G0
# BUILDING_CLASS_AT_TIME_OF_SALE_K2
# BUILDING_CLASS_AT_TIME_OF_SALE_D0
# BUILDING_CLASS_AT_TIME_OF_SALE_K8
# BUILDING_CLASS_AT_TIME_OF_SALE_A4
# BUILDING_CLASS_AT_TIME_OF_SALE_R6
# BUILDING_CLASS_AT_TIME_OF_SALE_RG
# BUILDING_CLASS_AT_TIME_OF_SALE_E1
# BUILDING_CLASS_AT_TIME_OF_SALE_I6
# BUILDING_CLASS_AT_TIME_OF_SALE_A6
# BUILDING_CLASS_AT_TIME_OF_SALE_C5
# BUILDING_CLASS_AT_TIME_OF_SALE_C8
# BUILDING_CLASS_AT_TIME_OF_SALE_K4
# BUILDING_CLASS_AT_TIME_OF_SALE_S5
# BUILDING_CLASS_AT_TIME_OF_SALE_D1
# BUILDING_CLASS_AT_TIME_OF_SALE_F9
# BUILDING_CLASS_AT_TIME_OF_SALE_O9
# BUILDING_CLASS_AT_TIME_OF_SALE_A8
# BUILDING_CLASS_AT_TIME_OF_SALE_E9
# BUILDING_CLASS_AT_TIME_OF_SALE_RK
# BUILDING_CLASS_AT_TIME_OF_SALE_O6
# BUILDING_CLASS_AT_TIME_OF_SALE_S4
# BUILDING_CLASS_AT_TIME_OF_SALE_J1
# BUILDING_CLASS_AT_TIME_OF_SALE_G6
# BUILDING_CLASS_AT_TIME_OF_SALE_M1
# BUILDING_CLASS_AT_TIME_OF_SALE_D9
# BUILDING_CLASS_AT_TIME_OF_SALE_G3
# BUILDING_CLASS_AT_TIME_OF_SALE_J6
# BUILDING_CLASS_AT_TIME_OF_SALE_O2
# BUILDING_CLASS_AT_TIME_OF_SALE_W2
# BUILDING_CLASS_AT_TIME_OF_SALE_R7
# BUILDING_CLASS_AT_TIME_OF_SALE_GW
# BUILDING_CLASS_AT_TIME_OF_SALE_K9
# BUILDING_CLASS_AT_TIME_OF_SALE_C9
# BUILDING_CLASS_AT_TIME_OF_SALE_F1
# BUILDING_CLASS_AT_TIME_OF_SALE_K7
# BUILDING_CLASS_AT_TIME_OF_SALE_RW
# BUILDING_CLASS_AT_TIME_OF_SALE_J2
# BUILDING_CLASS_AT_TIME_OF_SALE_O8
# BUILDING_CLASS_AT_TIME_OF_SALE_O1
# BUILDING_CLASS_AT_TIME_OF_SALE_F4
# BUILDING_CLASS_AT_TIME_OF_SALE_D2
# BUILDING_CLASS_AT_TIME_OF_SALE_K5
# BUILDING_CLASS_AT_TIME_OF_SALE_F8
# BUILDING_CLASS_AT_TIME_OF_SALE_R8
# BUILDING_CLASS_AT_TIME_OF_SALE_M9
# BUILDING_CLASS_AT_TIME_OF_SALE_RR
# BUILDING_CLASS_AT_TIME_OF_SALE_Q9
# BUILDING_CLASS_AT_TIME_OF_SALE_M3
# BUILDING_CLASS_AT_TIME_OF_SALE_S0
# BUILDING_CLASS_AT_TIME_OF_SALE_Z2
# BUILDING_CLASS_AT_TIME_OF_SALE_L9
# BUILDING_CLASS_AT_TIME_OF_SALE_E7
# BUILDING_CLASS_AT_TIME_OF_SALE_J9
# BUILDING_CLASS_AT_TIME_OF_SALE_E2
# BUILDING_CLASS_AT_TIME_OF_SALE_W8
# BUILDING_CLASS_AT_TIME_OF_SALE_R5
# BUILDING_CLASS_AT_TIME_OF_SALE_HB
# BUILDING_CLASS_AT_TIME_OF_SALE_H9
# BUILDING_CLASS_AT_TIME_OF_SALE_HR
# BUILDING_CLASS_AT_TIME_OF_SALE_I4
# BUILDING_CLASS_AT_TIME_OF_SALE_G8
# BUILDING_CLASS_AT_TIME_OF_SALE_H7
# BUILDING_CLASS_AT_TIME_OF_SALE_G9
# BUILDING_CLASS_AT_TIME_OF_SALE_I5
# BUILDING_CLASS_AT_TIME_OF_SALE_V9
# BUILDING_CLASS_AT_TIME_OF_SALE_RT
# BUILDING_CLASS_AT_TIME_OF_SALE_P8
# BUILDING_CLASS_AT_TIME_OF_SALE_Z4
# BUILDING_CLASS_AT_TIME_OF_SALE_L8
# BUILDING_CLASS_AT_TIME_OF_SALE_P2
# BUILDING_CLASS_AT_TIME_OF_SALE_L1
# BUILDING_CLASS_AT_TIME_OF_SALE_V3
# BUILDING_CLASS_AT_TIME_OF_SALE_T2
# BUILDING_CLASS_AT_TIME_OF_SALE_RA
# BUILDING_CLASS_AT_TIME_OF_SALE_G4
# BUILDING_CLASS_AT_TIME_OF_SALE_V2
# BUILDING_CLASS_AT_TIME_OF_SALE_H2
# BUILDING_CLASS_AT_TIME_OF_SALE_P9
# BUILDING_CLASS_AT_TIME_OF_SALE_W4
# BUILDING_CLASS_AT_TIME_OF_SALE_W3
# BUILDING_CLASS_AT_TIME_OF_SALE_I7
# BUILDING_CLASS_AT_TIME_OF_SALE_H4
# BUILDING_CLASS_AT_TIME_OF_SALE_K6

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error

for k in range(1, len(X_train.columns)+1):
    print(f'{k} features')

    selector = SelectKBest(score_func=f_regression, k=k)
    X_train_selected = selector.fit_transform(X_train, y_train)
    X_test_selected = selector.transform(X_test)

    model = LinearRegression()
    model.fit(X_train_selected, y_train)

    y_pred = model.predict(X_test_selected)
    mae = mean_absolute_error(y_test, y_pred)
    print(f'Test Mean Absolute Error: ${mae:,.0f} \n')
# Out:
# 1 features
# Test Mean Absolute Error: $1,781,542
#
# 2 features
# Test Mean Absolute Error: $1,781,576
#
# 3 features
# Test Mean Absolute Error: $1,752,095
#
# 4 features
# Test Mean Absolute Error: $1,752,154
#
# 5 features
# Test Mean Absolute Error: $1,732,841
#
# 6 features
# Test Mean Absolute Error: $1,732,888
#
# 7 features
# Test Mean Absolute Error: $1,724,107
#
# 8 features
# Test Mean Absolute Error: $1,721,429
#
# 9 features
# Test Mean Absolute Error: $1,847,399
#
# 10 features
# Test Mean Absolute Error: $1,846,154
#
# 11 features
# Test Mean Absolute Error: $1,845,902
#
# 12 features
# Test Mean Absolute Error: $1,845,902
#
# 13 features
# Test Mean Absolute Error: $1,831,285
#
# 14 features
# Test Mean Absolute Error: $1,830,984
#
# 15 features
# Test Mean Absolute Error: $1,834,080
#
# 16 features
# Test Mean Absolute Error: $1,827,132
#
# 17 features
# Test Mean Absolute Error: $1,826,881
#
# 18 features
# Test Mean Absolute Error: $1,819,155
#
# 19 features
# Test Mean Absolute Error: $1,819,187
#
# 20 features
# Test Mean Absolute Error: $1,815,470
#
# 21 features
# Test Mean Absolute Error: $1,816,993
#
# 22 features
# Test Mean Absolute Error: $1,816,881
#
# 23 features
# Test Mean Absolute Error: $1,816,881
#
# 24 features
# Test Mean Absolute Error: $1,818,658
#
# 25 features
# Test Mean Absolute Error: $1,812,671
#
# 26 features
# Test Mean Absolute Error: $1,812,671
#
# 27 features
# Test Mean Absolute Error: $1,811,967
#
# 28 features
# Test Mean Absolute Error: $1,814,089
#
# 29 features
# Test Mean Absolute Error: $1,809,646
#
# 30 features
# Test Mean Absolute Error: $1,809,646
#
# 31 features
# Test Mean Absolute Error: $1,809,650
#
# 32 features
# Test Mean Absolute Error: $1,805,663
#
# 33 features
# Test Mean Absolute Error: $1,805,662
#
# 34 features
# Test Mean Absolute Error: $1,805,540
#
# 35 features
# Test Mean Absolute Error: $1,805,572
#
# 36 features
# Test Mean Absolute Error: $1,802,939
#
# 37 features
# Test Mean Absolute Error: $1,802,939
#
# 38 features
# Test Mean Absolute Error: $1,802,850
#
# 39 features
# Test Mean Absolute Error: $1,805,639
#
# 40 features
# Test Mean Absolute Error: $1,824,755
#
# 41 features
# Test Mean Absolute Error: $1,825,609
#
# 42 features
# Test Mean Absolute Error: $1,828,543
#
# 43 features
# Test Mean Absolute Error: $1,828,543
#
# 44 features
# Test Mean Absolute Error: $1,828,038
#
# 45 features
# Test Mean Absolute Error: $1,828,038
#
# 46 features
# Test Mean Absolute Error: $1,831,266
#
# 47 features
# Test Mean Absolute Error: $1,830,132
#
# 48 features
# Test Mean Absolute Error: $1,830,132
#
# 49 features
# Test Mean Absolute Error: $1,830,114
#
# 50 features
# Test Mean Absolute Error: $1,832,917
#
# 51 features
# Test Mean Absolute Error: $1,832,917
#
# 52 features
# Test Mean Absolute Error: $1,833,143
#
# 53 features
# Test Mean Absolute Error: $1,833,236
#
# 54 features
# Test Mean Absolute Error: $1,832,004
#
# 55 features
# Test Mean Absolute Error: $1,832,004
#
# 56 features
# Test Mean Absolute Error: $1,832,004
#
# 57 features
# Test Mean Absolute Error: $1,831,507
#
# 58 features
# Test Mean Absolute Error: $1,831,440
#
# 59 features
# Test Mean Absolute Error: $1,831,440
#
# 60 features
# Test Mean Absolute Error: $1,832,063
#
# 61 features
# Test Mean Absolute Error: $1,831,977
#
# 62 features
# Test Mean Absolute Error: $1,835,284
#
# 63 features
# Test Mean Absolute Error: $1,856,578
#
# 64 features
# Test Mean Absolute Error: $1,835,270
#
# 65 features
# Test Mean Absolute Error: $1,834,375
#
# 66 features
# Test Mean Absolute Error: $1,834,375
#
# 67 features
# Test Mean Absolute Error: $1,834,813
#
# 68 features
# Test Mean Absolute Error: $1,848,032
#
# 69 features
# Test Mean Absolute Error: $1,831,394
#
# 70 features
# Test Mean Absolute Error: $1,822,460
#
# 71 features
# Test Mean Absolute Error: $1,827,937
#
# 72 features
# Test Mean Absolute Error: $1,834,079
#
# 73 features
# Test Mean Absolute Error: $1,825,599
#
# 74 features
# Test Mean Absolute Error: $1,835,548
#
# 75 features
# Test Mean Absolute Error: $1,821,108
#
# 76 features
# Test Mean Absolute Error: $1,826,552
#
# 77 features
# Test Mean Absolute Error: $10,106,154,151,355,038
#
# 78 features
# Test Mean Absolute Error: $1,014,708,856,448,304
#
# 79 features
# Test Mean Absolute Error: $4,650,436,349,334,698
#
# 80 features
# Test Mean Absolute Error: $3,369,601,956,907,628
#
# 81 features
# Test Mean Absolute Error: $3,059,636,720,460,234
#
# 82 features
# Test Mean Absolute Error: $12,029,536,234,199,862
#
# 83 features
# Test Mean Absolute Error: $3,201,242,253,670,945
#
# 84 features
# Test Mean Absolute Error: $175,797,283,269,036
#
# 85 features
# Test Mean Absolute Error: $4,464,414,279,346,298
#
# 86 features
# Test Mean Absolute Error: $869,758,139,428,830
#
# 87 features
# Test Mean Absolute Error: $13,040,693,581,958,530
#
# 88 features
# Test Mean Absolute Error: $2,663,000,719,136,928
#
# 89 features
# Test Mean Absolute Error: $14,455,254,765,014,828
#
# 90 features
# Test Mean Absolute Error: $13,150,583,088,379,398
#
# 91 features
# Test Mean Absolute Error: $12,675,983,399,274,614
#
# 92 features
# Test Mean Absolute Error: $15,508,109,361,017,072
#
# 93 features
# Test Mean Absolute Error: $6,450,489,124,279,890
#
# 94 features
# Test Mean Absolute Error: $16,290,074,514,561,948
#
# 95 features
# Test Mean Absolute Error: $4,602,486,499,676,763
#
# 96 features
# Test Mean Absolute Error: $5,367,222,394,361,349
#
# 97 features
# Test Mean Absolute Error: $4,439,068,378,731,312
#
# 98 features
# Test Mean Absolute Error: $447,020,800,656,101
#
# 99 features
# Test Mean Absolute Error: $4,502,773,236,548,012
#
# 100 features
# Test Mean Absolute Error: $4,149,612,256,643,392
#
# 101 features
# Test Mean Absolute Error: $15,118,531,054,897,746
#
# 102 features
# Test Mean Absolute Error: $19,375,268,033,431,836
#
# 103 features
# Test Mean Absolute Error: $18,123,105,050,712,572
#
# 104 features
# Test Mean Absolute Error: $15,494,550,041,842,706
#
# 105 features
# Test Mean Absolute Error: $11,315,186,063,772,628
#
# 106 features
# Test Mean Absolute Error: $6,544,633,571,728,158
#
# 107 features
# Test Mean Absolute Error: $2,543,570,545,253,366
#
# 108 features
# Test Mean Absolute Error: $10,953,225,820,926,286
#
# 109 features
# Test Mean Absolute Error: $7,378,783,898,741,811
#
# 110 features
# Test Mean Absolute Error: $7,030,865,632,343,917
#
# 111 features
# Test Mean Absolute Error: $10,991,280,218,138,802
#
# 112 features
# Test Mean Absolute Error: $4,356,938,741,347,376
#
# 113 features
# Test Mean Absolute Error: $17,425,181,138,573,180
#
# 114 features
# Test Mean Absolute Error: $17,081,790,304,245,304
#
# 115 features
# Test Mean Absolute Error: $18,429,551,452,665,748
#
# 116 features
# Test Mean Absolute Error: $14,641,236,917,210,230
#
# 117 features
# Test Mean Absolute Error: $14,808,734,642,714,522
#
# 118 features
# Test Mean Absolute Error: $13,501,853,299,711,452
#
# 119 features
# Test Mean Absolute Error: $16,761,979,048,520,044
#
# 120 features
# Test Mean Absolute Error: $18,992,300,960,056,676
#
# 121 features
# Test Mean Absolute Error: $14,814,386,674,206,258
#
# 122 features
# Test Mean Absolute Error: $26,473,937,597,736,044
#
# 123 features
# Test Mean Absolute Error: $17,432,389,611,548,586
#
# 124 features
# Test Mean Absolute Error: $14,955,807,405,156,130
#
# 125 features
# Test Mean Absolute Error: $14,590,232,284,299,690
#
# 126 features
# Test Mean Absolute Error: $25,168,157,828,222,048
#
# 127 features
# Test Mean Absolute Error: $909,436,254,938,496
#
# 128 features
# Test Mean Absolute Error: $1,844,353,389,119,894
#
# 129 features
# Test Mean Absolute Error: $60,730,773,996,111,288
#
# 130 features
# Test Mean Absolute Error: $141,884,759,731,401,024
#
# 131 features
# Test Mean Absolute Error: $520,295,087,978,885
#
# 132 features
# Test Mean Absolute Error: $7,280,618,401,710,983
#
# 133 features
# Test Mean Absolute Error: $6,222,324,619,071,424
#
# 134 features
# Test Mean Absolute Error: $7,172,525,814,401,479
#
# 135 features
# Test Mean Absolute Error: $2,222,645,100,903,244
#
# 136 features
# Test Mean Absolute Error: $8,196,582,754,912,859
#
# 137 features
# Test Mean Absolute Error: $8,042,659,517,143,153
#
# 138 features
# Test Mean Absolute Error: $7,310,731,947,361,540
#
# 139 features
# Test Mean Absolute Error: $4,429,692,039,472,230
#
# 140 features
# Test Mean Absolute Error: $7,926,388,834,047,913
#
# 141 features
# Test Mean Absolute Error: $6,422,291,500,029,688
#
# 142 features
# Test Mean Absolute Error: $8,942,700,488,632,673
#
# 143 features
# Test Mean Absolute Error: $5,211,480,999,460,460
#
# 144 features
# Test Mean Absolute Error: $4,668,444,119,118,746
#
# 145 features
# Test Mean Absolute Error: $5,768,025,870,496,171
#
# 146 features
# Test Mean Absolute Error: $91,799,971,387,600,640
#
# 147 features
# Test Mean Absolute Error: $80,397,684,885,283,456
#
# 148 features
# Test Mean Absolute Error: $7,833,154,036,979,795
#
# 149 features
# Test Mean Absolute Error: $7,982,340,927,484,560
#
# 150 features
# Test Mean Absolute Error: $9,265,605,723,233,744
#
# 151 features
# Test Mean Absolute Error: $114,089,768,282,398,320
#
# 152 features
# Test Mean Absolute Error: $8,362,014,156,220,868
#
# 153 features
# Test Mean Absolute Error: $97,148,678,271,118,704
#
# 154 features
# Test Mean Absolute Error: $6,398,366,160,465,611
#
# 155 features
# Test Mean Absolute Error: $61,576,092,368,012,720
#
# 156 features
# Test Mean Absolute Error: $9,237,644,202,042,920
#
# 157 features
# Test Mean Absolute Error: $6,865,083,812,280,416
#
# 158 features
# Test Mean Absolute Error: $3,677,984,129,817,192
#
# 159 features
# Test Mean Absolute Error: $8,210,092,196,064,882
#
# 160 features
# Test Mean Absolute Error: $102,425,213,781,905,632
#
# 161 features
# Test Mean Absolute Error: $387,950,487,761,840
#
# 162 features
# Test Mean Absolute Error: $3,941,644,858,941,904
#
# 163 features
# Test Mean Absolute Error: $5,490,456,519,298,590
#
# 164 features
# Test Mean Absolute Error: $88,691,225,837,170,080
#
# 165 features
# Test Mean Absolute Error: $63,908,375,031,643,448
#
# 166 features
# Test Mean Absolute Error: $103,734,820,425,180,176
#
# 167 features
# Test Mean Absolute Error: $4,079,802,165,660,668
#
# 168 features
# Test Mean Absolute Error: $3,642,095,291,103,233
#
# 169 features
# Test Mean Absolute Error: $3,940,004,601,548,944
#
# 170 features
# Test Mean Absolute Error: $6,497,873,331,974,717
#
# 171 features
# Test Mean Absolute Error: $9,501,528,618,432,058
#
# 172 features
# Test Mean Absolute Error: $8,157,898,626,993,752
#
# 173 features
# Test Mean Absolute Error: $26,446,571,908,548,400
#
# 174 features
# Test Mean Absolute Error: $21,976,411,428,445,928
#
# 175 features
# Test Mean Absolute Error: $30,568,960,541,717,484
#
# 176 features
# Test Mean Absolute Error: $7,795,876,307,297,860
#
# 177 features
# Test Mean Absolute Error: $5,983,769,141,551,959
#
# 178 features
# Test Mean Absolute Error: $117,082,778,182,310,768
#
# 179 features
# Test Mean Absolute Error: $173,625,045,720,828
#
# 180 features
# Test Mean Absolute Error: $40,302,425,320,089,152
#
# 181 features
# Test Mean Absolute Error: $42,443,674,472,012,760
#
# 182 features
# Test Mean Absolute Error: $43,532,568,049,239,160
#
# 183 features
# Test Mean Absolute Error: $24,189,408,654,154,596
#
# 184 features
# Test Mean Absolute Error: $70,748,771,602,706,200
#
# 185 features
# Test Mean Absolute Error: $50,505,402,939,241,936
#
# 186 features
# Test Mean Absolute Error: $26,552,342,544,331,276
#
# 187 features
# Test Mean Absolute Error: $47,446,383,175,437,336
#
# 188 features
# Test Mean Absolute Error: $7,535,362,512,997,828
#
# 189 features
# Test Mean Absolute Error: $71,903,024,467,092,568
#
# 190 features
# Test Mean Absolute Error: $3,630,574,014,494,977
#
# 191 features
# Test Mean Absolute Error: $84,726,599,352,104,736
#
# 192 features
# Test Mean Absolute Error: $70,804,694,593,906,304
#
# 193 features
# Test Mean Absolute Error: $89,371,069,426,848,528
#
# 194 features
# Test Mean Absolute Error: $25,488,839,514,886,884
#
# 195 features
# Test Mean Absolute Error: $35,041,338,063,330,168
#
# 196 features
# Test Mean Absolute Error: $12,752,722,420,986,106
#
# 197 features
# Test Mean Absolute Error: $36,360,483,100,893,976
#
# 198 features
# Test Mean Absolute Error: $43,327,753,324,239,696
#
# 199 features
# Test Mean Absolute Error: $64,889,545,821,854,776
#
# 200 features
# Test Mean Absolute Error: $105,983,535,393,692,016
#
# 201 features
# Test Mean Absolute Error: $46,604,054,370,819,880
#
# 202 features
# Test Mean Absolute Error: $4,140,003,002,247,904
#
# 203 features
# Test Mean Absolute Error: $100,370,715,721,889,648
#
# 204 features
# Test Mean Absolute Error: $26,789,359,472,289,324
#
# 205 features
# Test Mean Absolute Error: $76,273,446,078,484,224
#
# 206 features
# Test Mean Absolute Error: $69,065,005,240,450,136
#
# 207 features
# Test Mean Absolute Error: $114,680,963,978,170,672
#
# 208 features
# Test Mean Absolute Error: $71,848,512,711,144,104
#
# 209 features
# Test Mean Absolute Error: $45,945,601,559,375,664
#
# 210 features
# Test Mean Absolute Error: $127,197,002,674,814,768
#
# 211 features
# Test Mean Absolute Error: $49,201,881,256,724,816
#
# 212 features
# Test Mean Absolute Error: $39,262,906,726,068,488
#
# 213 features
# Test Mean Absolute Error: $34,334,547,826,513,076
#
# 214 features
# Test Mean Absolute Error: $63,246,324,663,530,576
#
# 215 features
# Test Mean Absolute Error: $13,203,362,758,072,836
#
# 216 features
# Test Mean Absolute Error: $37,022,579,411,449,656
#
# 217 features
# Test Mean Absolute Error: $3,294,322,400,497,006
#
# 218 features
# Test Mean Absolute Error: $140,323,099,015,404,048
#
# 219 features
# Test Mean Absolute Error: $99,904,853,290,753,872
#
# 220 features
# Test Mean Absolute Error: $92,547,956,291,379,920
#
# 221 features
# Test Mean Absolute Error: $91,640,317,088,479,568
#
# 222 features
# Test Mean Absolute Error: $77,744,223,295,278,144
#
# 223 features
# Test Mean Absolute Error: $98,805,274,945,666,784
#
# 224 features
# Test Mean Absolute Error: $103,905,334,856,871,648
#
# 225 features
# Test Mean Absolute Error: $74,724,032,346,518,304
#
# 226 features
# Test Mean Absolute Error: $71,974,336,536,369,672
#
# 227 features
# Test Mean Absolute Error: $31,797,523,226,510,464
#
# 228 features
# Test Mean Absolute Error: $75,875,434,707,667,744
#
# 229 features
# Test Mean Absolute Error: $146,819,460,486,090,528
#
# 230 features
# Test Mean Absolute Error: $67,280,868,171,573,368
#
# 231 features
# Test Mean Absolute Error: $93,410,338,916,833,664
#
# 232 features
# Test Mean Absolute Error: $35,052,477,163,538,456
#
# 233 features
# Test Mean Absolute Error: $97,790,483,034,701,200
#
# 234 features
# Test Mean Absolute Error: $64,448,180,922,125,176
#
# 235 features
# Test Mean Absolute Error: $65,775,006,436,023,096
#
# 236 features
# Test Mean Absolute Error: $37,662,358,627,598,192
#
# 237 features
# Test Mean Absolute Error: $43,071,478,901,395,032
#
# 238 features
# Test Mean Absolute Error: $75,202,521,531,607,904
#
# 239 features
# Test Mean Absolute Error: $45,310,430,177,565,256
#
# 240 features
# Test Mean Absolute Error: $74,383,493,433,646,144
#
# 241 features
# Test Mean Absolute Error: $58,061,199,491,500,176
#
# 242 features
# Test Mean Absolute Error: $74,844,691,498,671,792
#
# 243 features
# Test Mean Absolute Error: $69,798,272,678,401,424
#
# 244 features
# Test Mean Absolute Error: $38,742,844,784,319,800
#
# 245 features
# Test Mean Absolute Error: $49,091,898,665,985,080
#
# 246 features
# Test Mean Absolute Error: $32,970,788,471,745,192
#
# 247 features
# Test Mean Absolute Error: $48,703,930,620,486,784
#
# 248 features
# Test Mean Absolute Error: $36,116,282,502,810,824
#
# 249 features
# Test Mean Absolute Error: $35,070,572,194,538,264
#
# 250 features
# Test Mean Absolute Error: $53,578,566,616,086,600
#
# 251 features
# Test Mean Absolute Error: $100,378,059,538,064,800
#
# 252 features
# Test Mean Absolute Error: $75,343,042,739,223,408
#
# 253 features
# Test Mean Absolute Error: $21,278,177,179,060,276
#
# 254 features
# Test Mean Absolute Error: $24,403,734,258,084,752
#
# 255 features
# Test Mean Absolute Error: $65,700,864,626,625,848
#
# 256 features
# Test Mean Absolute Error: $73,706,061,388,638,496
#
# 257 features
# Test Mean Absolute Error: $51,118,434,198,487,768
#
# 258 features
# Test Mean Absolute Error: $54,995,812,900,703,952
#
# 259 features
# Test Mean Absolute Error: $48,640,817,950,697,256
#
# 260 features
# Test Mean Absolute Error: $66,628,640,666,672,216
#
# 261 features
# Test Mean Absolute Error: $70,576,728,180,360,144
#
# 262 features
# Test Mean Absolute Error: $77,143,110,289,485,616
#
# 263 features
# Test Mean Absolute Error: $65,633,056,960,423,512
#
# 264 features
# Test Mean Absolute Error: $43,504,206,487,555,160
#
# 265 features
# Test Mean Absolute Error: $48,370,734,764,217,472
#
# 266 features
# Test Mean Absolute Error: $44,441,884,279,079,040
#
# 267 features
# Test Mean Absolute Error: $49,422,048,601,892,720
#
# 268 features
# Test Mean Absolute Error: $44,738,559,576,184,104
#
# 269 features
# Test Mean Absolute Error: $45,799,635,946,564,760
#
# 270 features
# Test Mean Absolute Error: $65,096,074,014,328,648
#
# 271 features
# Test Mean Absolute Error: $32,435,695,198,534,128
#
# 272 features
# Test Mean Absolute Error: $43,240,177,296,902,096
#
# 273 features
# Test Mean Absolute Error: $24,084,173,260,878,596
#
# 274 features
# Test Mean Absolute Error: $14,234,648,528,948,850
#
# 275 features
# Test Mean Absolute Error: $27,287,228,947,965,164
#
# 276 features
# Test Mean Absolute Error: $33,621,222,981,961,496
#
# 277 features
# Test Mean Absolute Error: $54,938,120,064,343,952
#
# 278 features
# Test Mean Absolute Error: $77,990,539,240,807,520
#
# 279 features
# Test Mean Absolute Error: $30,917,772,415,407,624
#
# 280 features
# Test Mean Absolute Error: $24,738,188,635,897,092
#
# 281 features
# Test Mean Absolute Error: $34,066,695,891,356,404
#
# 282 features
# Test Mean Absolute Error: $30,488,229,429,567,388
#
# 283 features
# Test Mean Absolute Error: $54,720,039,239,697,288
#
# 284 features
# Test Mean Absolute Error: $28,335,557,162,771,064
#
# 285 features
# Test Mean Absolute Error: $16,729,862,752,003,384
#
# 286 features
# Test Mean Absolute Error: $57,513,054,164,572,872
#
# 287 features
# Test Mean Absolute Error: $20,547,289,249,211,836
#
# 288 features
# Test Mean Absolute Error: $8,135,116,730,743,026
#
# 289 features
# Test Mean Absolute Error: $71,290,705,651,916,984
#
# 290 features
# Test Mean Absolute Error: $53,478,270,614,215,096
#
# 291 features
# Test Mean Absolute Error: $60,006,720,321,658,024
#
# 292 features
# Test Mean Absolute Error: $74,479,422,588,134,912
#
# 293 features
# Test Mean Absolute Error: $16,559,342,116,979,384
#
# 294 features
# Test Mean Absolute Error: $63,674,523,483,364,984
#
# 295 features
# Test Mean Absolute Error: $68,450,191,778,682,160
#
# 296 features
# Test Mean Absolute Error: $32,355,452,083,483,348
#
# 297 features
# Test Mean Absolute Error: $37,650,102,475,966,800
#
# 298 features
# Test Mean Absolute Error: $32,727,450,341,920,500
#
# 299 features
# Test Mean Absolute Error: $41,281,729,535,656,744
#
# 300 features
# Test Mean Absolute Error: $43,726,495,200,506,680
#
# 301 features
# Test Mean Absolute Error: $37,016,946,986,605,672
#
# 302 features
# Test Mean Absolute Error: $28,347,432,934,587,356
#
# 303 features
# Test Mean Absolute Error: $30,010,964,946,890,888
#
# 304 features
# Test Mean Absolute Error: $8,253,645,623,152,997
#
# 305 features
# Test Mean Absolute Error: $10,366,390,066,021,226
#
# 306 features
# Test Mean Absolute Error: $39,965,526,638,774,928
#
# 307 features
# Test Mean Absolute Error: $53,412,850,448,312,400
#
# 308 features
# Test Mean Absolute Error: $40,677,015,859,814,256
#
# 309 features
# Test Mean Absolute Error: $23,722,577,810,540,388
#
# 310 features
# Test Mean Absolute Error: $27,819,453,143,352,340
#
# 311 features
# Test Mean Absolute Error: $33,330,242,168,389,492
#
# 312 features
# Test Mean Absolute Error: $44,699,580,367,935,432
#
# 313 features
# Test Mean Absolute Error: $29,983,936,057,952,600
#
# 314 features
# Test Mean Absolute Error: $33,379,458,100,061,172
#
# 315 features
# Test Mean Absolute Error: $35,000,782,272,083,652
#
# 316 features
# Test Mean Absolute Error: $23,304,985,524,966,736
#
# 317 features
# Test Mean Absolute Error: $30,618,199,034,819,212
#
# 318 features
# Test Mean Absolute Error: $21,764,266,265,995,148
#
# 319 features
# Test Mean Absolute Error: $24,283,596,074,824,136
#
# 320 features
# Test Mean Absolute Error: $19,523,287,927,721,304
#
# 321 features
# Test Mean Absolute Error: $29,060,458,226,611,204
#
# 322 features
# Test Mean Absolute Error: $24,243,352,937,800,224
#
# 323 features
# Test Mean Absolute Error: $16,780,661,610,453,878
#
# 324 features
# Test Mean Absolute Error: $29,271,622,128,684,768
#
# 325 features
# Test Mean Absolute Error: $52,091,487,652,083,664
#
# 326 features
# Test Mean Absolute Error: $16,470,874,239,589,430
#
# 327 features
# Test Mean Absolute Error: $56,883,520,338,306,184
#
# 328 features
# Test Mean Absolute Error: $31,877,892,723,711,304
#
# 329 features
# Test Mean Absolute Error: $30,178,662,678,357,692
#
# 330 features
# Test Mean Absolute Error: $40,416,574,804,255,808
#
# 331 features
# Test Mean Absolute Error: $16,121,630,278,069,038
#
# 332 features
# Test Mean Absolute Error: $27,392,702,225,210,692
#
# 333 features
# Test Mean Absolute Error: $48,693,801,151,458,784
#
# 334 features
# Test Mean Absolute Error: $112,495,048,820,761,392
#
# 335 features
# Test Mean Absolute Error: $103,334,015,264,564,016
#
# 336 features
# Test Mean Absolute Error: $31,459,963,300,961,016
#
# 337 features
# Test Mean Absolute Error: $24,596,993,835,568,164
#
# 338 features
# Test Mean Absolute Error: $63,781,115,423,395,448
#
# 339 features
# Test Mean Absolute Error: $34,817,063,850,828,900
#
# 340 features
# Test Mean Absolute Error: $33,397,549,615,723,448
#
# 341 features
# Test Mean Absolute Error: $29,433,626,982,919,660
#
# 342 features
# Test Mean Absolute Error: $83,614,972,955,487,056
#
# 343 features
# Test Mean Absolute Error: $98,814,118,726,539,488
#
# 344 features
# Test Mean Absolute Error: $40,031,513,379,081,424
#
# 345 features
# Test Mean Absolute Error: $66,244,182,171,429,672
#
# 346 features
# Test Mean Absolute Error: $44,007,468,958,408,936
#
# 347 features
# Test Mean Absolute Error: $25,322,160,823,412,996
#
# 348 features
# Test Mean Absolute Error: $67,340,722,088,830,480
#
# 349 features
# Test Mean Absolute Error: $101,604,181,511,951,712

# %%
# %matplotlib inline
from IPython.display import display, HTML
from ipywidgets import interact
import matplotlib.pyplot as plt
from sklearn.linear_model import Ridge
from sklearn.preprocessing import StandardScaler


# Try a range of alpha parameters for Ridge Regression.

# The scikit-learn docs explain, 
# alpha : Regularization strength; must be a positive float. Regularization 
# improves the conditioning of the problem and reduces the variance of the 
# estimates. Larger values specify stronger regularization.
# https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.Ridge.html

for alpha in [10**1, 10**2, 10**3, 10**4, 10**5, 10**6]:
    
    # Scale data before doing Ridge Regression
    scaler = StandardScaler()
    X_train_scaled = scaler.fit_transform(X_train)
    X_test_scaled = scaler.transform(X_test)
    
    # Fit Ridge Regression model
    display(HTML(f'Ridge Regression, with alpha={alpha}'))
    model = Ridge(alpha=alpha)
    model.fit(X_train_scaled, y_train)

    # Get Train MAE
    y_pred = model.predict(X_train_scaled)
    mae = mean_absolute_error(y_train, y_pred)
    display(HTML(f'Train Mean Absolute Error: ${mae:,.0f}'))

    # Get Test MAE
    y_pred = model.predict(X_test_scaled)
    mae = mean_absolute_error(y_test, y_pred)
    display(HTML(f'Test Mean Absolute Error: ${mae:,.0f}'))
    
    # Plot coefficients
    coefficients = pd.Series(model.coef_, X_train.columns)
    plt.figure(figsize=(16,8))
    coefficients.sort_values().plot.barh(color='grey')
    plt.xlim(-400,1000)
    plt.show()
# Out:
# Ridge Regression, with alpha=10
# Train Mean Absolute Error: $1,199,181
# Test Mean Absolute Error: $1,833,285
# Ridge Regression, with alpha=100
# Train Mean Absolute Error: $1,198,396
# Test Mean Absolute Error: $1,831,890
# Ridge Regression, with alpha=1000
# Train Mean Absolute Error: $1,190,607
# Test Mean Absolute Error: $1,819,046
# Ridge Regression, with alpha=10000
# Train Mean Absolute Error: $1,167,108
# Test Mean Absolute Error: $1,748,158
# Ridge Regression, with alpha=100000
# Train Mean Absolute Error: $1,290,746
# Test Mean Absolute Error: $1,712,913
# Ridge Regression, with alpha=1000000
# Train Mean Absolute Error: $1,433,228
# Test Mean Absolute Error: $1,782,027
